# %% [markdown]
# # Combining Data Frames

# %% [markdown]
# #### Import Pandas module

# %%
import pandas as pd

# %% [markdown]
# #### Load csv files into Pandas Data Frame

# %%
data_2015 = pd.read_csv("World Happiness Data 2015.csv")
data_2016 = pd.read_csv("World Happiness Data 2016.csv")
data_2017 = pd.read_csv("World Happiness Data 2017.csv")

# %%
data_2015
# Out:
#          Country                           Region  Happiness Rank  \
# 0    Switzerland                   Western Europe               1
# 1        Iceland                   Western Europe               2
# 2        Denmark                   Western Europe               3
# 3         Norway                   Western Europe               4
# 4         Canada                    North America               5
# ..           ...                              ...             ...
# 153       Rwanda               Sub-Saharan Africa             154
# 154        Benin               Sub-Saharan Africa             155
# 155        Syria  Middle East and Northern Africa             156
# 156      Burundi               Sub-Saharan Africa             157
# 157         Togo               Sub-Saharan Africa             158
#
#      Happiness Score  Standard Error  Economy (GDP per Capita)   Family  \
# 0              7.587         0.03411                   1.39651  1.34951
# ...

# %%
data_2016
# Out:
#          Country                           Region  Happiness Rank  \
# 0        Denmark                   Western Europe               1
# 1    Switzerland                   Western Europe               2
# 2        Iceland                   Western Europe               3
# 3         Norway                   Western Europe               4
# 4        Finland                   Western Europe               5
# ..           ...                              ...             ...
# 152        Benin               Sub-Saharan Africa             153
# 153  Afghanistan                    Southern Asia             154
# 154         Togo               Sub-Saharan Africa             155
# 155        Syria  Middle East and Northern Africa             156
# 156      Burundi               Sub-Saharan Africa             157
#
#      Happiness Score  Lower Confidence Interval  Upper Confidence Interval  \
# 0              7.526                      7.460                      7.592
# ...

# %%
data_2017
# Out:
#                       Country  Happiness.Rank  Happiness.Score  Whisker.high  \
# 0                      Norway               1            7.537      7.594445
# 1                     Denmark               2            7.522      7.581728
# 2                     Iceland               3            7.504      7.622030
# 3                 Switzerland               4            7.494      7.561772
# 4                     Finland               5            7.469      7.527542
# ..                        ...             ...              ...           ...
# 150                    Rwanda             151            3.471      3.543030
# 151                     Syria             152            3.462      3.663669
# 152                  Tanzania             153            3.349      3.461430
# 153                   Burundi             154            2.905      3.074690
# 154  Central African Republic             155            2.693      2.864884
#
# ...

# %% [markdown]
# #### Adding column with respective year value to each DataFrame

# %%
data_2015["Year"] = 2015
data_2016["Year"] = 2016
data_2017["Year"] = 2017

# %%
data_2015[["Year"]]
# Out:
#      Year
# 0    2015
# 1    2015
# 2    2015
# 3    2015
# 4    2015
# ..    ...
# 153  2015
# 154  2015
# 155  2015
# 156  2015
# 157  2015
#
# [158 rows x 1 columns]

# %% [markdown]
# ### Extracting same number of columns in two DataFrames with five values each

# %%
column_2015 = data_2015[["Country","Happiness Score","Year"]].head()
column_2016 = data_2016[["Country","Happiness Score","Year"]].head()

# %%
column_2015
# Out:
#        Country  Happiness Score  Year
# 0  Switzerland            7.587  2015
# 1      Iceland            7.561  2015
# 2      Denmark            7.527  2015
# 3       Norway            7.522  2015
# 4       Canada            7.427  2015

# %%
column_2016
# Out:
#        Country  Happiness Score  Year
# 0      Denmark            7.526  2016
# 1  Switzerland            7.509  2016
# 2      Iceland            7.501  2016
# 3       Norway            7.498  2016
# 4      Finland            7.413  2016

# %% [markdown]
# #### Joining the DataFrames in rows

# %%
pd.concat([column_2015,column_2016], axis = 0, ignore_index = True)
# Out:
#        Country  Happiness Score  Year
# 0  Switzerland            7.587  2015
# 1      Iceland            7.561  2015
# 2      Denmark            7.527  2015
# 3       Norway            7.522  2015
# 4       Canada            7.427  2015
# 5      Denmark            7.526  2016
# 6  Switzerland            7.509  2016
# 7      Iceland            7.501  2016
# 8       Norway            7.498  2016
# 9      Finland            7.413  2016

# %% [markdown]
# #### Joining the DataFrames in columns

# %%
pd.concat([column_2015,column_2016], axis = 1)
# Out:
#        Country  Happiness Score  Year      Country  Happiness Score  Year
# 0  Switzerland            7.587  2015      Denmark            7.526  2016
# 1      Iceland            7.561  2015  Switzerland            7.509  2016
# 2      Denmark            7.527  2015      Iceland            7.501  2016
# 3       Norway            7.522  2015       Norway            7.498  2016
# 4       Canada            7.427  2015      Finland            7.413  2016

# %% [markdown]
# ### Extractiong different number of columns in two DataFrames with five values each

# %%
columns_2015 = data_2015[["Country","Happiness Score","Year","Happiness Rank"]].head()
columns_2016 = data_2016[["Country","Happiness Score","Year"]].head()

# %%
columns_2015
# Out:
#        Country  Happiness Score  Year  Happiness Rank
# 0  Switzerland            7.587  2015               1
# 1      Iceland            7.561  2015               2
# 2      Denmark            7.527  2015               3
# 3       Norway            7.522  2015               4
# 4       Canada            7.427  2015               5

# %%
columns_2016
# Out:
#        Country  Happiness Score  Year
# 0      Denmark            7.526  2016
# 1  Switzerland            7.509  2016
# 2      Iceland            7.501  2016
# 3       Norway            7.498  2016
# 4      Finland            7.413  2016

# %% [markdown]
# #### Joining DataFrames in rows

# %%
pd.concat([column_2015,column_2016], axis = 0, ignore_index = True)
# Out:
#        Country  Happiness Score  Year
# 0  Switzerland            7.587  2015
# 1      Iceland            7.561  2015
# 2      Denmark            7.527  2015
# 3       Norway            7.522  2015
# 4       Canada            7.427  2015
# 5      Denmark            7.526  2016
# 6  Switzerland            7.509  2016
# 7      Iceland            7.501  2016
# 8       Norway            7.498  2016
# 9      Finland            7.413  2016

# %% [markdown]
# #### Joining DataFrames in columns

# %%
pd.concat([column_2015,column_2016], axis = 1)
# Out:
#        Country  Happiness Score  Year      Country  Happiness Score  Year
# 0  Switzerland            7.587  2015      Denmark            7.526  2016
# 1      Iceland            7.561  2015  Switzerland            7.509  2016
# 2      Denmark            7.527  2015      Iceland            7.501  2016
# 3       Norway            7.522  2015       Norway            7.498  2016
# 4       Canada            7.427  2015      Finland            7.413  2016

# %% [markdown]
# ### Renaming column of "data_2017" for joining DataFrame

# %%
data_2017.rename({"Happiness.Score":"Happiness Score"},axis = 1, inplace = True)

# %%
data_2017
# Out:
#                       Country  Happiness.Rank  Happiness Score  Whisker.high  \
# 0                      Norway               1            7.537      7.594445
# 1                     Denmark               2            7.522      7.581728
# 2                     Iceland               3            7.504      7.622030
# 3                 Switzerland               4            7.494      7.561772
# 4                     Finland               5            7.469      7.527542
# ..                        ...             ...              ...           ...
# 150                    Rwanda             151            3.471      3.543030
# 151                     Syria             152            3.462      3.663669
# 152                  Tanzania             153            3.349      3.461430
# 153                   Burundi             154            2.905      3.074690
# 154  Central African Republic             155            2.693      2.864884
#
# ...

# %% [markdown]
# ### Extracting same number of columns in all DataFrames with five values each

# %%
column_2015 = data_2015[["Country","Happiness Score","Year"]].head()
column_2016 = data_2016[["Country","Happiness Score","Year"]].head()
column_2017 = data_2017[["Country","Happiness Score","Year"]].head()

# %% [markdown]
# #### Joining the DataFrames in rows

# %%
pd.concat([column_2015, column_2016, column_2017], axis = 0, ignore_index = True)
# Out:
#         Country  Happiness Score  Year
# 0   Switzerland            7.587  2015
# 1       Iceland            7.561  2015
# 2       Denmark            7.527  2015
# 3        Norway            7.522  2015
# 4        Canada            7.427  2015
# 5       Denmark            7.526  2016
# 6   Switzerland            7.509  2016
# 7       Iceland            7.501  2016
# 8        Norway            7.498  2016
# 9       Finland            7.413  2016
# 10       Norway            7.537  2017
# 11      Denmark            7.522  2017
# 12      Iceland            7.504  2017
# 13  Switzerland            7.494  2017
# 14      Finland            7.469  2017

# %% [markdown]
# #### Joining the DataFrames in columns

# %%
pd.concat([column_2015, column_2016, column_2017], axis = 1)
# Out:
#        Country  Happiness Score  Year      Country  Happiness Score  Year  \
# 0  Switzerland            7.587  2015      Denmark            7.526  2016
# 1      Iceland            7.561  2015  Switzerland            7.509  2016
# 2      Denmark            7.527  2015      Iceland            7.501  2016
# 3       Norway            7.522  2015       Norway            7.498  2016
# 4       Canada            7.427  2015      Finland            7.413  2016
#
#        Country  Happiness Score  Year
# 0       Norway            7.537  2017
# 1      Denmark            7.522  2017
# 2      Iceland            7.504  2017
# 3  Switzerland            7.494  2017
# 4      Finland            7.469  2017

# %% [markdown]
# # Merging DataFrames

# %%
column_2015
# Out:
#        Country  Happiness Score  Year
# 0  Switzerland            7.587  2015
# 1      Iceland            7.561  2015
# 2      Denmark            7.527  2015
# 3       Norway            7.522  2015
# 4       Canada            7.427  2015

# %%
column_2016
# Out:
#        Country  Happiness Score  Year
# 0      Denmark            7.526  2016
# 1  Switzerland            7.509  2016
# 2      Iceland            7.501  2016
# 3       Norway            7.498  2016
# 4      Finland            7.413  2016

# %% [markdown]
# ### inner

# %%
pd.merge(left = column_2015, right = column_2016, how = "inner", on = "Country", suffixes=(" 2015", " 2016"))
# Out:
#        Country  Happiness Score 2015  Year 2015  Happiness Score 2016  \
# 0  Switzerland                 7.587       2015                 7.509
# 1      Iceland                 7.561       2015                 7.501
# 2      Denmark                 7.527       2015                 7.526
# 3       Norway                 7.522       2015                 7.498
#
#    Year 2016
# 0       2016
# 1       2016
# 2       2016
# 3       2016

# %% [markdown]
# ### left

# %%
pd.merge(left = column_2015, right = column_2016, how = "left", on = "Country", suffixes=(" 2015", " 2016"))
# Out:
#        Country  Happiness Score 2015  Year 2015  Happiness Score 2016  \
# 0  Switzerland                 7.587       2015                 7.509
# 1      Iceland                 7.561       2015                 7.501
# 2      Denmark                 7.527       2015                 7.526
# 3       Norway                 7.522       2015                 7.498
# 4       Canada                 7.427       2015                   NaN
#
#    Year 2016
# 0     2016.0
# 1     2016.0
# 2     2016.0
# 3     2016.0
# 4        NaN

# %% [markdown]
# ### right

# %%
pd.merge(left = column_2015, right = column_2016, how = "right", on = "Country", suffixes=(" 2015", " 2016"))
# Out:
#        Country  Happiness Score 2015  Year 2015  Happiness Score 2016  \
# 0      Denmark                 7.527     2015.0                 7.526
# 1  Switzerland                 7.587     2015.0                 7.509
# 2      Iceland                 7.561     2015.0                 7.501
# 3       Norway                 7.522     2015.0                 7.498
# 4      Finland                   NaN        NaN                 7.413
#
#    Year 2016
# 0       2016
# 1       2016
# 2       2016
# 3       2016
# 4       2016
